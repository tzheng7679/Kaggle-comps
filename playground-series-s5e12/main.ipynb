# %%
import pandas as pd
import torch
import xgboost
import seaborn as sns

# %%
train = pd.read_csv("train.csv").drop(labels="id", axis=1)
train.head()

diagnosed_col = "diagnosed_diabetes"

# %%
pd.get_dummies(train).corr().pipe(sns.heatmap, cmap="crest")
# Out:
# <Axes: >

# %%
train.melt(id_vars=diagnosed_col)

# %%
train.columns[0:len(train.columns)//4]
# Out:
# Index(['age', 'alcohol_consumption_per_week',
#        'physical_activity_minutes_per_week', 'diet_score',
#        'sleep_hours_per_day', 'screen_time_hours_per_day'],
#       dtype='object')
